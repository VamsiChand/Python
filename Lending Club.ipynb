# %%
acc=pd.read_csv('accepted_2007_to_2018Q4.csv')
# Out:
# C:\Users\personal\Anaconda3_NEW\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (0,19,49,59,118,129,130,131,134,135,136,139,145,146,147) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
import pandas as pd

# %%
acc.shape
# Out:
# (2260701, 151)

# %%
acc['issue_d'].
# Out:
# array(['Dec-2015', 'Nov-2015', 'Oct-2015', 'Sep-2015', 'Aug-2015',
#        'Jul-2015', 'Jun-2015', 'May-2015', 'Apr-2015', 'Mar-2015',
#        'Feb-2015', 'Jan-2015', nan, 'Mar-2018', 'Feb-2018', 'Jan-2018',
#        'Sep-2017', 'Aug-2017', 'Jul-2017', 'Jun-2016', 'May-2016',
#        'Apr-2016', 'Sep-2018', 'Aug-2018', 'Jul-2018', 'Jun-2017',
#        'May-2017', 'Apr-2017', 'Mar-2016', 'Feb-2016', 'Jan-2016',
#        'Dec-2014', 'Nov-2014', 'Oct-2014', 'Sep-2014', 'Aug-2014',
#        'Jul-2014', 'Jun-2014', 'May-2014', 'Apr-2014', 'Mar-2014',
#        'Feb-2014', 'Jan-2014', 'Dec-2018', 'Nov-2018', 'Oct-2018',
#        'Jun-2018', 'May-2018', 'Apr-2018', 'Dec-2011', 'Nov-2011',
#        'Oct-2011', 'Sep-2011', 'Aug-2011', 'Jul-2011', 'Jun-2011',
#        'May-2011', 'Apr-2011', 'Mar-2011', 'Feb-2011', 'Jan-2011',
#        'Dec-2010', 'Nov-2010', 'Oct-2010', 'Sep-2010', 'Aug-2010',
#        'Jul-2010', 'Jun-2010', 'May-2010', 'Apr-2010', 'Mar-2010',
# ...

# %%
acc.columns.tolist()
# Out:
# ['id',
#  'member_id',
#  'loan_amnt',
#  'funded_amnt',
#  'funded_amnt_inv',
#  'term',
#  'int_rate',
#  'installment',
#  'grade',
#  'sub_grade',
#  'emp_title',
#  'emp_length',
#  'home_ownership',
#  'annual_inc',
#  'verification_status',
#  'issue_d',
#  'loan_status',
#  'pymnt_plan',
#  'url',
#  'desc',
#  'purpose',
#  'title',
#  'zip_code',
#  'addr_state',
#  'dti',
#  'delinq_2yrs',
#  'earliest_cr_line',
#  'fico_range_low',
#  'fico_range_high',
#  'inq_last_6mths',
#  'mths_since_last_delinq',
#  'mths_since_last_record',
#  'open_acc',
#  'pub_rec',
#  'revol_bal',
#  'revol_util',
#  'total_acc',
#  'initial_list_status',
#  'out_prncp',
#  'out_prncp_inv',
#  'total_pymnt',
#  'total_pymnt_inv',
#  'total_rec_prncp',
#  'total_rec_int',
#  'total_rec_late_fee',
#  'recoveries',
#  'collection_recovery_fee',
#  'last_pymnt_d',
#  'last_pymnt_amnt',
#  'next_pymnt_d',
#  'last_credit_pull_d',
#  'last_fico_range_high',
#  'last_fico_range_low',
# ...

# %%
Quart=pd.read_csv('Year_Quarter Mapping.csv')

# %%
import datetime as dt

# %%
Acc=pd.merge(acc,Quart,on='issue_d')

# %%
B=Acc.groupby([ "issue_year","issue_Quarter"])

# %%
Quart.columns
# Out:
# Index(['issue_d', 'issue_Quarter', 'issue_year'], dtype='object')

# %%
B
# Out:
#     issue_year issue_Quarter      id
# 0         2007            Q3     190
# 1         2007            Q4     389
# 2         2008            Q1    1013
# 3         2008            Q2     374
# 4         2008            Q3     298
# 5         2008            Q4     584
# 6         2009            Q1     895
# 7         2009            Q2     692
# 8         2009            Q3    1364
# 9         2009            Q4    1924
# 10        2010            Q1    2172
# 11        2010            Q2    1901
# 12        2010            Q3    3568
# 13        2010            Q4    3791
# 14        2011            Q1    4126
# 15        2011            Q2    3267
# 16        2011            Q3    5876
# 17        2011            Q4    6617
# 18        2012            Q1    8076
# 19        2012            Q2    6630
# 20        2012            Q3   16133
# 21        2012            Q4   18711
# 22        2013            Q1   22706
# 23        2013            Q2   19769
# ...

# %%
B=Acc.pivot_table(index=('issue_year','issue_Quarter'),values='id',aggfunc='count').reset_index()

# %%
piv = pd.pivot_table(Acc, index=['issue_Quarter'],columns=['issue_year'], values=['id'],aggfunc='count')

# %%
import seaborn as sns

# %%
piv.plot()

# %%
import seaborn as sns
sns.barplot(data=B,x=['issue_year','issue_Quarter'],y='id')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\Anaconda3_NEW\lib\site-packages\seaborn\utils.py in categorical_order(values, order)
#     525             try:
# --> 526                 order = values.cat.categories
#     527             except (TypeError, AttributeError):
#
# ~\Anaconda3_NEW\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#
# AttributeError: 'DataFrame' object has no attribute 'cat'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~\Anaconda3_NEW\lib\site-packages\seaborn\utils.py in categorical_order(values, order)
#     528                 try:
# --> 529                     order = values.unique()
# ...

# %%
B
# Out:
#     issue_year issue_Quarter      id
# 0         2007            Q3     190
# 1         2007            Q4     389
# 2         2008            Q1    1013
# 3         2008            Q2     374
# 4         2008            Q3     298
# 5         2008            Q4     584
# 6         2009            Q1     895
# 7         2009            Q2     692
# 8         2009            Q3    1364
# 9         2009            Q4    1924
# 10        2010            Q1    2172
# 11        2010            Q2    1901
# 12        2010            Q3    3568
# 13        2010            Q4    3791
# 14        2011            Q1    4126
# 15        2011            Q2    3267
# 16        2011            Q3    5876
# 17        2011            Q4    6617
# 18        2012            Q1    8076
# 19        2012            Q2    6630
# 20        2012            Q3   16133
# 21        2012            Q4   18711
# 22        2013            Q1   22706
# 23        2013            Q2   19769
# ...

# %%
B['y']=B['issue_year']+ ' ' + B['issue_Quarter']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3_NEW\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#    1504         try:
# -> 1505             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#    1506         except TypeError:
#
# ~\Anaconda3_NEW\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     207     if use_numexpr:
# --> 208         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     209     return _evaluate_standard(op, op_str, a, b)
#
# ~\Anaconda3_NEW\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b, truediv, reversed, **eval_kwargs)
#     122     if result is None:
# --> 123         result = _evaluate_standard(op, op_str, a, b)
#     124
#
# ...
